# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !cp gdrive/My\ Drive/upload/a4.zip .

# %%
# !ls
# Out:
# a4.zip	gdrive	sample_data

# %%
# !unzip a4.zip
# Out:
# Archive:  a4.zip
#    creating: a4/
#   inflating: a4/README.md
#  extracting: a4/__init__.py
#    creating: a4/__pycache__/
#   inflating: a4/__pycache__/model_embeddings.cpython-37.pyc
#   inflating: a4/__pycache__/nmt_model.cpython-37.pyc
#   inflating: a4/__pycache__/utils.cpython-37.pyc
#   inflating: a4/__pycache__/vocab.cpython-37.pyc
#   inflating: a4/collect_submission.sh
#    creating: a4/en_es_data/
#   inflating: a4/en_es_data/dev.en
#   inflating: a4/en_es_data/dev.es
#   inflating: a4/en_es_data/test.en
#   inflating: a4/en_es_data/test.es
#   inflating: a4/en_es_data/train.en
#   inflating: a4/en_es_data/train.es
#  extracting: a4/gpu_requirements.txt
#   inflating: a4/local_env.yml
#   inflating: a4/model_embeddings.py
#   inflating: a4/nmt_model.py
#   inflating: a4/run.py
#   inflating: a4/run.sh
#   inflating: a4/sanity_check.py
#    creating: a4/sanity_check_en_es_data/
#   inflating: a4/sanity_check_en_es_data/Ybar_t.pkl
# ...

# %%
# !ls
# Out:
# a4  a4.zip  gdrive  sample_data

# %%
import torch

# %%
# %cd a4
# Out:
# /content/a4

# %%
# !./run.sh train
# Out:
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 167.86, avg. ppl 24454.35 cum. examples 320, speed 2586.83 words/sec, time elapsed 2.06 sec
# epoch 1, iter 20, avg. loss 142.46, avg. ppl 3202.44 cum. examples 640, speed 3070.03 words/sec, time elapsed 3.89 sec
# epoch 1, iter 30, avg. loss 138.59, avg. ppl 1845.80 cum. examples 960, speed 3109.26 words/sec, time elapsed 5.79 sec
# epoch 1, iter 40, avg. loss 131.75, avg. ppl 1768.42 cum. examples 1280, speed 2916.57 words/sec, time elapsed 7.72 sec
# epoch 1, iter 50, avg. loss 132.24, avg. ppl 1541.06 cum. examples 1600, speed 3204.48 words/sec, time elapsed 9.52 sec
# epoch 1, iter 60, avg. loss 127.33, avg. ppl 1379.26 cum. examples 1920, speed 3080.10 words/sec, time elapsed 11.35 sec
# epoch 1, iter 70, avg. loss 118.07, avg. ppl 1329.85 cum. examples 2240, speed 2964.26 words/sec, time elapsed 13.13 sec
# ...

# %%
# !./run.sh test
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [10:35<00:00, 12.69it/s]
# Corpus BLEU: 22.51906462908753
# Traceback (most recent call last):
#   File "run.py", line 343, in <module>
#     main()
#   File "run.py", line 337, in main
#     decode(args)
#   File "run.py", line 289, in decode
#     with open(args['OUTPUT_FILE'], 'w') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/test_outputs.txt'

# %%
# !ls
# Out:
# sample_data
